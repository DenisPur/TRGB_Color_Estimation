# %%
from pathlib import Path
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from reader import *

# %%
filename = Path('./raw/NGC1156.phot.WEB')

# %%
define_type(filename)
# Out:
# 'type_1'

# %%
data = read_type1(filename)
data
# Out:
#        extension        x        y   mag_v   mag_i  type   snr_v  snr_i  \
# 0              0  3414.79  1924.24  18.408  17.413     1  1056.5  987.0
# 1              0  1266.50   480.71  18.322  17.547     1   757.0  943.6
# 2              0   239.08  3344.61  18.891  17.600     1   857.0  887.8
# 3              0  2085.69  1206.84  18.884  18.044     1   830.5  741.7
# 4              0  3123.64  3513.66  19.550  18.501     1   635.3  605.2
# ...          ...      ...      ...     ...     ...   ...     ...    ...
# 55480          0   591.55  3197.79  28.392  26.270     1     3.5    6.7
# 55481          0  2045.43  2895.48  28.131  26.025     1     3.1    6.2
# 55482          0  2656.50  3380.49  28.254  25.924     1     3.5    8.2
# 55483          0  2508.99  2156.26  27.698  25.200     1     3.7    9.0
# 55484          0  1084.60  2729.68  28.111  25.583     1     4.5   11.0
#
#        flag_v  flag_i  crowd_v  crowd_i  sharp_v  sharp_i  err_v  err_i
# 0           0       0    0.021    0.025   -0.079   -0.034  0.001  0.001
# 1           0       0    0.015    0.011   -0.039   -0.039  0.001  0.001
# 2           0       0    0.055    0.039   -0.010    0.007  0.001  0.001
# 3           0       0    0.017    0.014   -0.037    0.008  0.001  0.001
# 4           0       0    0.013    0.015   -0.011    0.007  0.002  0.002
# ...       ...     ...      ...      ...      ...      ...    ...    ...
# 55480       0       0    0.298    0.122   -0.101    0.352  0.309  0.162
# 55481       0       0    0.425    0.320   -0.091    0.070  0.345  0.176
# 55482       0       0    0.028    0.016   -0.184    0.321  0.308  0.132
# 55483       0       0    0.471    0.199    0.005    0.199  0.296  0.120
# 55484       0       0    0.022    0.019    0.022    0.079  0.242  0.099
#
# [55485 rows x 16 columns]

# %%
sns.scatterplot(data=data, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
data.to_csv('./converted/' + filename.name.split('.')[0] + '.csv', index=None)
