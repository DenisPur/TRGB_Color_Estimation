# %%
from pathlib import Path
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from readers import *

# %%
filename = Path('./raw/IC1613.phot.WEB')

# %%
define_type(filename)
# Out:
# 'type_4'

# %%
data = read_type4(filename)
data
# Out:
#        extension  type       x       y   mag_v   mag_i   snr_v   snr_i  \
# 0              0     1  264.29  711.28  21.723  19.112   362.7  1349.1
# 1              0     1  628.54  714.87  19.781  19.707  1044.3   999.0
# 2              0     1   96.44  460.09  19.964  19.549   522.8  1091.7
# 3              0     1  201.11  509.71  20.261  20.181   308.6   799.2
# 4              0     1  732.04  109.23  21.937  19.906   307.4   915.9
# ...          ...   ...     ...     ...     ...     ...     ...     ...
# 25297          3     1  161.30   89.03  99.999  99.999     5.0     0.0
# 25298          3     1  325.69  107.92  99.999  99.999     0.0     5.7
# 25299          3     1  446.62  307.30  99.999  99.999     0.0     5.3
# 25300          3     1  552.66  278.45  99.999  99.999     0.0     5.1
# 25301          3     1  717.47  115.10  99.999  99.999     0.0     5.2
#
#        sharp_v  sharp_i  round_v  round_i  err_v  err_i
# 0       -0.022    0.002    0.014    0.006  0.003  0.001
# 1       -0.016   -0.027    0.024    0.006  0.001  0.001
# 2        0.064    0.006    0.033    0.005  0.002  0.001
# 3       -0.003   -0.008    0.040    0.017  0.004  0.001
# 4       -0.003    0.008    0.052    0.013  0.004  0.001
# ...        ...      ...      ...      ...    ...    ...
# 25297    0.453    0.000    0.545    0.000  0.216  0.000
# 25298    0.000   -0.087    0.000    0.472  0.000  0.192
# 25299    0.000    0.143    0.000   -0.079  0.000  0.207
# 25300    0.000    0.261    0.000    0.270  0.000  0.211
# 25301    0.000    0.250    0.000    1.942  0.000  0.210
#
# [25302 rows x 14 columns]

# %%
data = synch_coordinates_wfcs(data)

# %%
sns.scatterplot(data=data, s=1, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
data.to_csv('./converted/' + filename.name.split('.')[0] + '.csv', index=None)
