# %%
from pathlib import Path
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from readers import *

# %%
filename = Path('./raw/NGC3738.phot.WEB')

# %%
define_type(filename)
# Out:
# 'type_6'

# %%
data = read_type6(filename)
data
# Out:
#         extension        x        y  type   mag_v  err_v  snr_v  sharp_v  \
# 0               1  2136.64  1225.75     1  22.473  0.005  201.0    0.001
# 1               1  4038.87   482.59     1  22.070  0.005  213.6   -0.006
# 2               1   969.95  1345.54     1  22.745  0.008  143.9   -0.031
# 3               1  2020.91  2015.30     1  22.508  0.010  110.1    0.050
# 4               1  2006.08  1906.41     1  23.023  0.008  131.0   -0.037
# ...           ...      ...      ...   ...     ...    ...    ...      ...
# 115118          2  3224.56   100.73     1  27.551  0.219    5.0    0.079
# 115119          2  2426.35  1488.92     1  27.810  0.217    5.0    0.031
# 115120          2  3365.51  1597.62     1  27.749  0.192    5.6    0.162
# 115121          2  2464.99   906.48     1  27.012  0.179    6.1    0.135
# 115122          2  2678.08  1234.45     1  27.693  0.202    5.4    0.107
#
#         round_v  crowd_v  flag_v   mag_i  err_i  snr_i  sharp_i  round_i  \
# 0         0.059    0.000       0  19.218  0.002  467.8    0.039    0.026
# 1         0.105    0.000       0  20.705  0.005  231.8    0.003    0.085
# 2         0.083    0.000       2  20.680  0.005  232.2    0.020   -0.019
# 3         0.477    0.083       0  20.921  0.008  133.9    0.033    0.159
# 4         0.043    0.002       0  20.912  0.005  197.6    0.006    0.003
# ...         ...      ...     ...     ...    ...    ...      ...      ...
# 115118    0.211    0.305       0  26.399  0.213    5.1    0.206    0.088
# 115119    2.332    0.333       0  26.662  0.203    5.4    0.122    0.329
# 115120    0.472    0.586       0  26.390  0.166    6.6    0.191    1.098
# 115121    5.667    1.371       0  25.991  0.180    6.0    0.208    4.615
# 115122    0.059    0.744       0  26.170  0.160    6.8    0.141    0.280
#
#         crowd_i  flag_i
# 0         0.000       0
# 1         0.000       0
# 2         0.000       0
# 3         0.061       0
# 4         0.002       0
# ...         ...     ...
# 115118    0.295       0
# 115119    0.279       0
# 115120    0.640       0
# 115121    1.183       0
# 115122    0.671       0
#
# [115123 rows x 18 columns]

# %%
# data = synch_coordinates_wfcs(data)
data = synch_coordinates_acs(data)

# %%
sns.scatterplot(data=data, s=1, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
data.to_csv('./converted/' + filename.name.split('.')[0] + '.csv', index=None)
